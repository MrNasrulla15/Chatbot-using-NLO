# %%
# !git clone https://github.com/RGS-AI/Chatbot_using_NLP_AICTE_Cycle4.git
# Out:
# Cloning into 'Chatbot_using_NLP_AICTE_Cycle4'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 5.68 KiB | 5.68 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
